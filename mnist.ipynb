# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import torch
from torch import nn
from torch.utils.data import DataLoader
from torch.utils.data import Dataset
import torchvision

import jax
import jax.numpy as jnp

from sklearn.model_selection import train_test_split

# %%
train_df=pd.read_csv("/kaggle/input/digit-recognizer/train.csv")
test_df=pd.read_csv("/kaggle/input/digit-recognizer/test.csv")

# %%
len(train_df)
# Out:
# 42000

# %%
X=train_df.copy()
y=X.pop("label")
X_train,X_val,y_train,y_val=train_test_split(X,y,test_size=0.2)

# %%
class DigitRecognizer(Dataset):
    def __init__(self, train,transform=None,target_transform=None):
        if train:
            self.df=X_train.copy()
            self.labels=y_train.copy()
        else:
            self.df=X_val.copy()
            self.labels=y_val.copy()
        self.transform=transform
        self.target_transform=target_transform
        
    def __len__(self):
        return len(self.labels)
        
    def __getitem__(self,idx):
        label=self.labels.iloc[idx]
        image=torch.tensor(self.df.iloc[idx].values).type(torch.float)
        if self.transform:
            image=self.transform(image)
        if self.target_transform:
            label=self.target_transform(label)
        return image, label

# %%
train_loader=DataLoader(DigitRecognizer(train=True), batch_size=64, shuffle=True)
test_loader=DataLoader(DigitRecognizer(train=False), batch_size=64, shuffle=True)

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"

# %%
class MnistModel1(nn.Module):
    def __init__(self):
        super().__init__()
        self.linear_stack=nn.Sequential(
            nn.Linear(784,10),
            nn.ReLU(),
            nn.Linear(10,10),
            nn.ReLU(),
            nn.Linear(10,10)
        )

    def forward(self,x):
        return self.linear_stack(x)


model=MnistModel1().to(device)
model
# Out:
# MnistModel1(
#   (linear_stack): Sequential(
#     (0): Linear(in_features=784, out_features=10, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=10, out_features=10, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=10, out_features=10, bias=True)
#   )
# )

# %%
loss_fn=nn.CrossEntropyLoss()
optimizer=torch.optim.SGD(model.parameters(), lr=0.001)

# %%
def train(dataloader,model,loss_fn,optimizer):
    model.train()
    for i,(X,y) in enumerate(dataloader):
        X=X.to(device)
        y=y.to(device)
        pred=model(X)
        loss=loss_fn(pred,y)
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()
        if i%100==0:
            print(f"Batch {i}, Loss {loss.item()}")
    
    
def test(dataloader, model, loss_fn):
    size=len(dataloader.dataset)
    num_batches=len(dataloader)
    model.eval()
    test_loss, correct=0,0
    with torch.no_grad():
        for X,y in dataloader:
            X=X.to(device)
            y=y.to(device)
            pred=model(X)
            test_loss+=loss_fn(pred,y).item()
            correct+= (pred.argmax(1)==y).type(torch.float).sum().item()
    test_loss/=num_batches
    correct/=size
    print(f"Test Error: \n Accuracy: {(100*correct):>0.1f}%, Avg loss: {test_loss:>8f} \n")

# %%
epochs=50
for i in range(epochs):
    print(f"Epoch {i}")
    train(train_loader,model,loss_fn,optimizer)
    test(test_loader,model,loss_fn)
# Out:
# Epoch 0
# Batch 0, Loss 13.489460945129395
# Batch 100, Loss 1.649893879890442
# Batch 200, Loss 1.4109688997268677
# Batch 300, Loss 1.352682113647461
# Batch 400, Loss 1.1536303758621216
# Batch 500, Loss 0.8712546825408936
# Test Error:
#  Accuracy: 70.8%, Avg loss: 1.072456
#
# Epoch 1
# Batch 0, Loss 1.2207920551300049
# Batch 100, Loss 1.075443983078003
# Batch 200, Loss 0.9196873903274536
# Batch 300, Loss 0.6816635131835938
# Batch 400, Loss 1.0095579624176025
# Batch 500, Loss 0.8226373195648193
# Test Error:
#  Accuracy: 74.2%, Avg loss: 0.921234
#
# Epoch 2
# Batch 0, Loss 0.6789654493331909
# Batch 100, Loss 1.1001297235488892
# Batch 200, Loss 0.7210519313812256
# Batch 300, Loss 0.48322418332099915
# Batch 400, Loss 0.5225216150283813
# Batch 500, Loss 0.7411543726921082
# Test Error:
#  Accuracy: 78.8%, Avg loss: 0.683123
#
# Epoch 3
# Batch 0, Loss 0.6714595556259155
# Batch 100, Loss 0.690265417098999
# Batch 200, Loss 0.6972518563270569
# Batch 300, Loss 0.5277186632156372
# Batch 400, Loss 0.4449980556964874
# Batch 500, Loss 0.8293686509132385
# Test Error:
#  Accuracy: 84.9%, Avg loss: 0.547633
#
# Epoch 4
# Batch 0, Loss 0.526220440864563
# Batch 100, Loss 0.39175134897232056
# Batch 200, Loss 0.6434299945831299
# Batch 300, Loss 0.7969422340393066
# Batch 400, Loss 0.4551392197608948
# Batch 500, Loss 0.5789189338684082
# Test Error:
#  Accuracy: 86.9%, Avg loss: 0.466944
#
# Epoch 5
# Batch 0, Loss 0.17641578614711761
# Batch 100, Loss 0.4951487183570862
# Batch 200, Loss 0.25497737526893616
# Batch 300, Loss 0.687254786491394
# Batch 400, Loss 0.4495191276073456
# Batch 500, Loss 0.44793716073036194
# Test Error:
#  Accuracy: 87.3%, Avg loss: 0.451848
#
# Epoch 6
# Batch 0, Loss 0.35823485255241394
# Batch 100, Loss 0.41164711117744446
# Batch 200, Loss 0.23197858035564423
# Batch 300, Loss 0.24726885557174683
# Batch 400, Loss 0.3594602644443512
# Batch 500, Loss 0.2578447461128235
# Test Error:
#  Accuracy: 88.5%, Avg loss: 0.414292
#
# Epoch 7
# Batch 0, Loss 0.380088746547699
# Batch 100, Loss 0.6172434091567993
# Batch 200, Loss 0.45715612173080444
# Batch 300, Loss 0.6238734126091003
# Batch 400, Loss 0.2756724953651428
# Batch 500, Loss 0.35646578669548035
# Test Error:
#  Accuracy: 88.8%, Avg loss: 0.398811
#
# Epoch 8
# Batch 0, Loss 0.27685412764549255
# Batch 100, Loss 0.5306414365768433
# Batch 200, Loss 0.26594024896621704
# Batch 300, Loss 0.2878108024597168
# Batch 400, Loss 0.2704579830169678
# Batch 500, Loss 0.17609117925167084
# Test Error:
#  Accuracy: 89.2%, Avg loss: 0.382328
#
# Epoch 9
# Batch 0, Loss 0.10816160589456558
# Batch 100, Loss 0.4477090835571289
# Batch 200, Loss 0.406486839056015
# Batch 300, Loss 0.37963223457336426
# Batch 400, Loss 0.4710147976875305
# Batch 500, Loss 0.402798056602478
# Test Error:
#  Accuracy: 90.0%, Avg loss: 0.361352
#
# Epoch 10
# Batch 0, Loss 0.3944810628890991
# Batch 100, Loss 0.20362338423728943
# Batch 200, Loss 0.5006381273269653
# Batch 300, Loss 0.6552063226699829
# Batch 400, Loss 0.20187318325042725
# Batch 500, Loss 0.3030489683151245
# Test Error:
#  Accuracy: 90.0%, Avg loss: 0.351698
#
# Epoch 11
# Batch 0, Loss 0.10259851068258286
# Batch 100, Loss 0.38198092579841614
# Batch 200, Loss 0.2672973871231079
# Batch 300, Loss 0.4539797008037567
# Batch 400, Loss 0.46919363737106323
# Batch 500, Loss 0.2206534594297409
# Test Error:
#  Accuracy: 89.7%, Avg loss: 0.358059
#
# Epoch 12
# Batch 0, Loss 0.16623055934906006
# Batch 100, Loss 0.4173898696899414
# Batch 200, Loss 0.2996021509170532
# Batch 300, Loss 0.3913480043411255
# Batch 400, Loss 0.2971627116203308
# Batch 500, Loss 0.3026791512966156
# Test Error:
#  Accuracy: 90.2%, Avg loss: 0.337869
#
# Epoch 13
# Batch 0, Loss 0.37894362211227417
# Batch 100, Loss 0.2867349684238434
# Batch 200, Loss 0.3654201030731201
# Batch 300, Loss 0.12976546585559845
# Batch 400, Loss 0.49464717507362366
# Batch 500, Loss 0.3727480173110962
# Test Error:
#  Accuracy: 90.1%, Avg loss: 0.340759
#
# Epoch 14
# Batch 0, Loss 0.26236966252326965
# Batch 100, Loss 0.1642332673072815
# Batch 200, Loss 0.47665902972221375
# Batch 300, Loss 0.3054710328578949
# Batch 400, Loss 0.4272306561470032
# Batch 500, Loss 0.2431926131248474
# Test Error:
#  Accuracy: 90.6%, Avg loss: 0.331723
#
# Epoch 15
# Batch 0, Loss 0.33898091316223145
# Batch 100, Loss 0.3511982560157776
# Batch 200, Loss 0.21738462150096893
# Batch 300, Loss 0.2662332355976105
# Batch 400, Loss 0.3519570827484131
# Batch 500, Loss 0.26363280415534973
# Test Error:
#  Accuracy: 90.3%, Avg loss: 0.330207
#
# Epoch 16
# Batch 0, Loss 0.2431313693523407
# Batch 100, Loss 0.23970597982406616
# Batch 200, Loss 0.3656231164932251
# Batch 300, Loss 0.2970336377620697
# Batch 400, Loss 0.16345378756523132
# Batch 500, Loss 0.5741297006607056
# Test Error:
#  Accuracy: 89.5%, Avg loss: 0.348842
#
# Epoch 17
# Batch 0, Loss 0.2808624804019928
# Batch 100, Loss 0.4120456278324127
# Batch 200, Loss 0.17161136865615845
# Batch 300, Loss 0.3726978003978729
# Batch 400, Loss 0.2940109074115753
# Batch 500, Loss 0.23538419604301453
# Test Error:
#  Accuracy: 90.7%, Avg loss: 0.324553
#
# Epoch 18
# Batch 0, Loss 0.18699154257774353
# Batch 100, Loss 0.4714966416358948
# Batch 200, Loss 0.264093816280365
# Batch 300, Loss 0.2964094877243042
# Batch 400, Loss 0.07604886591434479
# Batch 500, Loss 0.2805526852607727
# Test Error:
#  Accuracy: 90.6%, Avg loss: 0.321031
#
# Epoch 19
# Batch 0, Loss 0.17035695910453796
# Batch 100, Loss 0.4755679965019226
# Batch 200, Loss 0.4318542182445526
# Batch 300, Loss 0.27815863490104675
# Batch 400, Loss 0.2378586232662201
# Batch 500, Loss 0.21565592288970947
# Test Error:
#  Accuracy: 90.6%, Avg loss: 0.320958
#
# Epoch 20
# Batch 0, Loss 0.5321581363677979
# Batch 100, Loss 0.08314725756645203
# Batch 200, Loss 0.22248387336730957
# Batch 300, Loss 0.39662209153175354
# Batch 400, Loss 0.21000607311725616
# Batch 500, Loss 0.22390037775039673
# Test Error:
#  Accuracy: 90.3%, Avg loss: 0.328222
#
# Epoch 21
# Batch 0, Loss 0.1841796487569809
# Batch 100, Loss 0.19926117360591888
# Batch 200, Loss 0.37190020084381104
# Batch 300, Loss 0.16279006004333496
# Batch 400, Loss 0.2202140837907791
# Batch 500, Loss 0.1963358223438263
# Test Error:
#  Accuracy: 90.5%, Avg loss: 0.326721
#
# Epoch 22
# Batch 0, Loss 0.4063672721385956
# Batch 100, Loss 0.2447323054075241
# Batch 200, Loss 0.11809128522872925
# Batch 300, Loss 0.24279595911502838
# Batch 400, Loss 0.17691273987293243
# Batch 500, Loss 0.40724658966064453
# Test Error:
#  Accuracy: 90.7%, Avg loss: 0.321643
#
# Epoch 23
# Batch 0, Loss 0.19468948245048523
# Batch 100, Loss 0.22978724539279938
# Batch 200, Loss 0.3494296967983246
# Batch 300, Loss 0.39769041538238525
# Batch 400, Loss 0.2955043315887451
# Batch 500, Loss 0.2872873544692993
# Test Error:
#  Accuracy: 90.7%, Avg loss: 0.317925
#
# Epoch 24
# Batch 0, Loss 0.26723745465278625
# Batch 100, Loss 0.18416135013103485
# Batch 200, Loss 0.42043888568878174
# Batch 300, Loss 0.2312326580286026
# Batch 400, Loss 0.15863406658172607
# Batch 500, Loss 0.15021567046642303
# Test Error:
#  Accuracy: 90.7%, Avg loss: 0.321125
#
# Epoch 25
# Batch 0, Loss 0.37928828597068787
# Batch 100, Loss 0.3856995105743408
# Batch 200, Loss 0.5052741765975952
# Batch 300, Loss 0.16380852460861206
# Batch 400, Loss 0.2605334222316742
# Batch 500, Loss 0.1538674235343933
# Test Error:
#  Accuracy: 91.0%, Avg loss: 0.313000
#
# Epoch 26
# Batch 0, Loss 0.1571785807609558
# Batch 100, Loss 0.10639242082834244
# Batch 200, Loss 0.2849741578102112
# Batch 300, Loss 0.18755647540092468
# Batch 400, Loss 0.2468721866607666
# Batch 500, Loss 0.17155009508132935
# Test Error:
#  Accuracy: 90.8%, Avg loss: 0.319804
#
# Epoch 27
# Batch 0, Loss 0.2590884268283844
# Batch 100, Loss 0.3088237941265106
# Batch 200, Loss 0.1967582255601883
# Batch 300, Loss 0.15248507261276245
# Batch 400, Loss 0.3016998767852783
# Batch 500, Loss 0.20936062932014465
# Test Error:
#  Accuracy: 90.8%, Avg loss: 0.319116
#
# Epoch 28
# Batch 0, Loss 0.20619377493858337
# Batch 100, Loss 0.20450806617736816
# Batch 200, Loss 0.30753612518310547
# Batch 300, Loss 0.30369240045547485
# Batch 400, Loss 0.16353975236415863
# Batch 500, Loss 0.1581900268793106
# Test Error:
#  Accuracy: 90.6%, Avg loss: 0.322001
#
# Epoch 29
# Batch 0, Loss 0.19134023785591125
# Batch 100, Loss 0.3486301600933075
# Batch 200, Loss 0.2836897373199463
# Batch 300, Loss 0.3139892816543579
# Batch 400, Loss 0.25888311862945557
# Batch 500, Loss 0.19992652535438538
# Test Error:
#  Accuracy: 91.2%, Avg loss: 0.312218
#
# Epoch 30
# Batch 0, Loss 0.20075519382953644
# Batch 100, Loss 0.2970702052116394
# Batch 200, Loss 0.18321895599365234
# Batch 300, Loss 0.39474987983703613
# Batch 400, Loss 0.24745914340019226
# Batch 500, Loss 0.3044518232345581
# Test Error:
#  Accuracy: 90.6%, Avg loss: 0.321573
#
# Epoch 31
# Batch 0, Loss 0.14232027530670166
# Batch 100, Loss 0.33710822463035583
# Batch 200, Loss 0.1668659746646881
# Batch 300, Loss 0.21743687987327576
# Batch 400, Loss 0.3080347180366516
# Batch 500, Loss 0.32720836997032166
# Test Error:
#  Accuracy: 90.7%, Avg loss: 0.322015
#
# Epoch 32
# Batch 0, Loss 0.20953238010406494
# Batch 100, Loss 0.2613629102706909
# Batch 200, Loss 0.14140547811985016
# Batch 300, Loss 0.3949689567089081
# Batch 400, Loss 0.24883174896240234
# Batch 500, Loss 0.19550776481628418
# Test Error:
#  Accuracy: 90.8%, Avg loss: 0.313556
#
# Epoch 33
# Batch 0, Loss 0.1008167564868927
# Batch 100, Loss 0.18486906588077545
# Batch 200, Loss 0.2215310037136078
# Batch 300, Loss 0.2693394720554352
# Batch 400, Loss 0.37500765919685364
# Batch 500, Loss 0.32395559549331665
# Test Error:
#  Accuracy: 91.1%, Avg loss: 0.307092
#
# Epoch 34
# Batch 0, Loss 0.2855757772922516
# Batch 100, Loss 0.21554456651210785
# Batch 200, Loss 0.31464555859565735
# Batch 300, Loss 0.15594157576560974
# Batch 400, Loss 0.26880979537963867
# Batch 500, Loss 0.09214230626821518
# Test Error:
#  Accuracy: 91.1%, Avg loss: 0.313007
#
# Epoch 35
# Batch 0, Loss 0.10238131135702133
# Batch 100, Loss 0.15866295993328094
# Batch 200, Loss 0.34525054693222046
# Batch 300, Loss 0.24614784121513367
# Batch 400, Loss 0.18652626872062683
# Batch 500, Loss 0.2232876569032669
# Test Error:
#  Accuracy: 91.2%, Avg loss: 0.310985
#
# Epoch 36
# Batch 0, Loss 0.14148257672786713
# Batch 100, Loss 0.27722564339637756
# Batch 200, Loss 0.15212254226207733
# Batch 300, Loss 0.21267767250537872
# Batch 400, Loss 0.4289505183696747
# Batch 500, Loss 0.07312944531440735
# Test Error:
#  Accuracy: 90.9%, Avg loss: 0.322103
#
# Epoch 37
# Batch 0, Loss 0.09038309007883072
# Batch 100, Loss 0.20613078773021698
# Batch 200, Loss 0.3582921028137207
# Batch 300, Loss 0.23039336502552032
# Batch 400, Loss 0.4147350788116455
# Batch 500, Loss 0.10864122211933136
# Test Error:
#  Accuracy: 90.7%, Avg loss: 0.317018
#
# Epoch 38
# Batch 0, Loss 0.10826639831066132
# Batch 100, Loss 0.3190936744213104
# Batch 200, Loss 0.4301220774650574
# Batch 300, Loss 0.2836313843727112
# Batch 400, Loss 0.09351662546396255
# Batch 500, Loss 0.30572518706321716
# Test Error:
#  Accuracy: 91.4%, Avg loss: 0.304221
#
# Epoch 39
# Batch 0, Loss 0.19849328696727753
# Batch 100, Loss 0.5511201024055481
# Batch 200, Loss 0.21575136482715607
# Batch 300, Loss 0.1189952939748764
# Batch 400, Loss 0.2481645792722702
# Batch 500, Loss 0.24004071950912476
# Test Error:
#  Accuracy: 91.0%, Avg loss: 0.320222
#
# Epoch 40
# Batch 0, Loss 0.19062529504299164
# Batch 100, Loss 0.16266123950481415
# Batch 200, Loss 0.23761405050754547
# Batch 300, Loss 0.26538631319999695
# Batch 400, Loss 0.046723224222660065
# Batch 500, Loss 0.21223589777946472
# Test Error:
#  Accuracy: 91.4%, Avg loss: 0.303331
#
# Epoch 41
# Batch 0, Loss 0.33793339133262634
# Batch 100, Loss 0.1736334264278412
# Batch 200, Loss 0.4617587924003601
# Batch 300, Loss 0.18290124833583832
# Batch 400, Loss 0.2748507857322693
# Batch 500, Loss 0.12215776741504669
# Test Error:
#  Accuracy: 90.6%, Avg loss: 0.326521
#
# Epoch 42
# Batch 0, Loss 0.13247086107730865
# Batch 100, Loss 0.3414115905761719
# Batch 200, Loss 0.17805634438991547
# Batch 300, Loss 0.19655613601207733
# Batch 400, Loss 0.3885887861251831
# Batch 500, Loss 0.28231287002563477
# Test Error:
#  Accuracy: 91.0%, Avg loss: 0.311334
#
# Epoch 43
# Batch 0, Loss 0.16363923251628876
# Batch 100, Loss 0.25682905316352844
# Batch 200, Loss 0.19463127851486206
# Batch 300, Loss 0.09314347803592682
# Batch 400, Loss 0.0895891934633255
# Batch 500, Loss 0.46678051352500916
# Test Error:
#  Accuracy: 91.4%, Avg loss: 0.307640
#
# Epoch 44
# Batch 0, Loss 0.16347429156303406
# Batch 100, Loss 0.15958799421787262
# Batch 200, Loss 0.27856025099754333
# Batch 300, Loss 0.3163069486618042
# Batch 400, Loss 0.030693544074892998
# Batch 500, Loss 0.5052326917648315
# Test Error:
#  Accuracy: 91.6%, Avg loss: 0.301789
#
# Epoch 45
# Batch 0, Loss 0.1629488468170166
# Batch 100, Loss 0.1606532484292984
# Batch 200, Loss 0.0310239065438509
# Batch 300, Loss 0.20215246081352234
# Batch 400, Loss 0.2688770294189453
# Batch 500, Loss 0.14060178399085999
# Test Error:
#  Accuracy: 90.8%, Avg loss: 0.313218
#
# Epoch 46
# Batch 0, Loss 0.12773333489894867
# Batch 100, Loss 0.17892010509967804
# Batch 200, Loss 0.1244172751903534
# Batch 300, Loss 0.09387174248695374
# Batch 400, Loss 0.32784542441368103
# Batch 500, Loss 0.299465537071228
# Test Error:
#  Accuracy: 90.8%, Avg loss: 0.313708
#
# Epoch 47
# Batch 0, Loss 0.17238245904445648
# Batch 100, Loss 0.1736505776643753
# Batch 200, Loss 0.36583763360977173
# Batch 300, Loss 0.42576566338539124
# Batch 400, Loss 0.14091791212558746
# Batch 500, Loss 0.1567796766757965
# Test Error:
#  Accuracy: 91.1%, Avg loss: 0.311967
#
# Epoch 48
# Batch 0, Loss 0.11720627546310425
# Batch 100, Loss 0.5459361672401428
# Batch 200, Loss 0.14932477474212646
# Batch 300, Loss 0.13305741548538208
# Batch 400, Loss 0.12350190430879593
# Batch 500, Loss 0.17714431881904602
# Test Error:
#  Accuracy: 91.0%, Avg loss: 0.309152
#
# Epoch 49
# Batch 0, Loss 0.23355597257614136
# Batch 100, Loss 0.2686205804347992
# Batch 200, Loss 0.1123834177851677
# Batch 300, Loss 0.41710004210472107
# Batch 400, Loss 0.1511448621749878
# Batch 500, Loss 0.21149298548698425
# Test Error:
#  Accuracy: 91.8%, Avg loss: 0.300123

# %%
test_df=pd.read_csv("/kaggle/input/digit-recognizer/test.csv")
X_test=torch.tensor(test_df.to_numpy()).type(torch.float).to(device)
X_test.shape
y=model(X_test)
s=nn.Softmax(dim=1)
preds=torch.argmax(s(y), dim=1).to("cpu").numpy()

# %%
submission=pd.read_csv("/kaggle/input/digit-recognizer/sample_submission.csv", index_col="ImageId")
submission["Label"]=preds
submission.to_csv("/kaggle/working/submission.csv")
